# %%
## 1st Part

# %%
maxDistance = int(100)
temperature = float(25.5)
greetIng = str("Greeting")
isRaining = bool(True)

# %%
maxDistance
# Out:
# 100

# %%
temperature
# Out:
# 25.5

# %%
greetIng
# Out:
# 'Greeting'

# %%
isRaining
# Out:
# True

# %%
## 2nd Part

# %%
value_1st = 1

# %%
totalAmount = 25

# %%
calcNum = 25.5

# %%
dataEntry = "Data"

# %%
## 3rd Part

# %%
float(int(42))
# Out:
# 42.0

# %%
int(float(3.14159))
# Out:
# 3

# %%
str(float(99.99))
# Out:
# '99.99'

# %%
float(str(float(99.99)))
# Out:
# 99.99

# %%
## 4th Part

# %%
type(maxDistance)
# Out:
# int

# %%
type(temperature)
# Out:
# float

# %%
type(isRaining)
# Out:
# bool

# %%
type(greetIng)
# Out:
# str
