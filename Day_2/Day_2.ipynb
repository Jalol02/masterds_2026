# %%
# This is a single - line comment
"""
comment
"""
# code block example
if True:
    print("This statement is inside an if block")
    
print("This statement is outside the if block")
# Out:
# This statement is inside an if block
# This statement is outside the if block

# %% [markdown]
# ### Exercise #1

# %%
if 10>5:
    print("Ten is greater than five")
# Out:
# Ten is greater than five

# %%
if 10>50:
    print("Ten is greater than five")
else:
    print("It is lower")
    
#print("Today is sunny")
# Out:
# It is lower

# %%
def sum(a, b): # Create function
    """
    This function solves an arithmetical sum of two variables (a and b)
    """
    result = a+b # Sum of a and b
    return(result) # Show the result

# %%
x = int(5)
y = int(4.9)
#int(a)
#int(b)
sum(x,y)
# Out:
# 9

# %%
sum("Mike", " Elisa")
# Out:
# 'Mike Elisa'

# %%
sum(4.6, 8.9)
# Out:
# 13.5

# %%
sum(False, True)
# Out:
# 1

# %% [markdown]
# ### Demo

# %% [markdown]
# #### ex 1

# %%
a = 5
b = 5.7
c = "Text"
d = True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5.7

# %%
c
# Out:
# 'Text'

# %%
d
# Out:
# True

# %% [markdown]
# #### ex 2

# %%
data1 = 5
value2 = 5.7
this_is_a_string = "Text"
number_of_students = False

# %% [markdown]
# #### ex 3

# %%
str(data1)
# Out:
# '5'

# %%
value2 = int(value2)
value2
# Out:
# 5

# %%
float(number_of_students)
# Out:
# 0.0

# %% [markdown]
# #### ex 4

# %%
type(number_of_students)
# Out:
# bool

# %%
type(value2)
# Out:
# int

# %%
type(5>5)
# Out:
# bool

# %%
d = str(number_of_students)
d
# Out:
# 'False'
