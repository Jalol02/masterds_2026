# %% [markdown]
# #### Ex 1

# %%
print(f'Hello {name}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f'Hello {name}')
#
# NameError: name 'name' is not defined

# %%
try:
    print(f'Hello {name}')

except NameError:
    print('No {name} defined')
# Out:
# No {name} defined

# %% [markdown]
# #### Ex 2

# %%
try:
    x = 10 + "ABC"
    
except TypeError:
    print("Can't concatenate int and string")
# Out:
# Can't concatenate int and string

# %% [markdown]
# #### Ex 3

# %%
try:
    list = [1,2,3,4,5]
    list[7]

except IndexError as e:
    print(f"Can't find index from the list, {e} ")
# Out:
# Can't find index from the list, list index out of range

# %% [markdown]
# #### Ex 4

# %%
try:
    x = 10/0
except ZeroDivisionError as e:
    print(f"Error, '{e}' has occured")
# Out:
# Error, 'division by zero' has occured
