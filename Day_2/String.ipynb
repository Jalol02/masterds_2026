# %%
s = 'I have an idea'
s
# Out:
# 'I have an idea'

# %%
sc = "I heard that 'I need my own opinion' "
sc
# Out:
# "I heard that 'I need my own opinion' "

# %%
''' Multi line strings
    This is also string
'''
# Out:
# ' Multi line strings\n    This is also string\n'

# %%
s + " " + sc
# Out:
# "I have an idea I heard that 'I need my own opinion' "

# %%
len(s)
# Out:
# 14

# %%
s[0:10]
# Out:
# 'I have an '

# %%
s[0:10:2]
# Out:
# 'Ihv n'

# %%
sc.upper()
# Out:
# "I HEARD THAT 'I NEED MY OWN OPINION' "

# %%
sc.lower()
# Out:
# "i heard that 'i need my own opinion' "

# %%
sc.find("that")
# Out:
# 8

# %%
sc.replace("need", "should have".upper())
# Out:
# "I heard that 'I SHOULD HAVE my own opinion' "

# %%
name = "Jaloliddin" 
"Hello, %s"%name # OLD style
# Out:
# 'Hello, Jaloliddin'

# %%
print('Hello, {}'.format(name)) # str.format()
# Out:
# Hello, Jaloliddin

# %%
f'Hello, {name}' # f-Strings
# Out:
# 'Hello, Jaloliddin'

# %%
print(f'Hello, \n {name}')
# Out:
# Hello,
#  Jaloliddin
