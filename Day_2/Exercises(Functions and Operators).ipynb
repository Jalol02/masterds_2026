# %% [markdown]
# #### ex 1

# %%
a = float(input("First number: "))
b = float(input("Second number: "))
# Out:
# First number:  25
# Second number:  54

# %%
def num_func(a,b):
    print("Sum is", a+b)
    print("Difference is", a-b)
    print("Multiplication is", a*b)
    print("Remainder is", a%b)
    print("Power is", a**b)

# %%
num_func(a,b)
# Out:
# Sum is 79.0
# Difference is -29.0
# Multiplication is 1350.0
# Remainder is 25.0
# Power is 3.0814879110195775e+75

# %% [markdown]
# #### ex 2

# %%
c = int(99)
c
# Out:
# 99

# %%
c+= (c+a)
c
# Out:
# 223.0

# %%
c += (c-b)
c
# Out:
# 392.0

# %%
c += (c*a)
c
# Out:
# 10192.0

# %%
c += (c%a)
c
# Out:
# 10209.0

# %%
c += (c**a)
c
# Out:
# 1.6771816238695136e+100

# %% [markdown]
# #### ex 3

# %%
a = 5
b = 6
c = 4
a,b,c
# Out:
# (5, 6, 4)

# %%
a ==b
# Out:
# False

# %%
a > c
# Out:
# True

# %%
c != b
# Out:
# True

# %% [markdown]
# #### ex 4

# %%
a<b and c<a
# True and True
# Out:
# True

# %%
a<b or c<a
# True or True
# Out:
# True

# %%
a>c and c==b
# True and False
# False
# Out:
# False
