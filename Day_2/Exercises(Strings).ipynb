# %% [markdown]
# #### ex 1

# %%
'Single quotes'
# Out:
# 'Single quotes'

# %%
"Doulbe quotes"
# Out:
# 'Doulbe quotes'

# %%
"""
    Multiple line string
    2nd line
"""
# Out:
# '\n    Multiple line string\n    2nd line\n'

# %% [markdown]
# #### ex 2

# %%
name = "Jaloliddin"
surname = "Akhmedov"

# %%
print(f'Hello, {name} {surname}!')
# Out:
# Hello, Jaloliddin Akhmedov!

# %% [markdown]
# #### ex 3

# %%
a = "Hello world"
b = a[:2] + a[-2:]

# %%
b
# Out:
# 'Held'

# %% [markdown]
# #### ex 4

# %%
a[:2].lower()
# Out:
# 'he'

# %%
a[-2:].upper()
# Out:
# 'LD'
