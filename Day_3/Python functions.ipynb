# %% [markdown]
# #### Ex 1

# %%
def calculate_area(h,w):
    '''
    Area is equal to height * width
    '''
    return h*w

# %%
calculate_area(h=10, w=5)
# Out:
# 50

# %% [markdown]
# #### Ex 2

# %%
def introduce(name, age=25):
    print(f"Hello, my name is {name}, I am {age} years old")

# %%
introduce("Jalol", 30)
# Out:
# Hello, my name is Jalol, I am 30 years old

# %% [markdown]
# #### Ex 3

# %%
def first_last(x):
    return x[0], x[-1]

# %%
x = [1,2,5,10]
first_last(x)
# Out:
# (1, 10)
