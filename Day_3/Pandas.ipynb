# %%
#### Ex 1

# %%
import pandas as pd

# %%
my_dict = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}

# %%
pd.DataFrame(my_dict)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
#### Ex 2

# %%
auto_prices = pd.read_csv('../Datasets/automobile_prices.csv')
auto_prices.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN      ferrari       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          3                NaN  alfa-romero       gas        std
# 3          1                NaN  alfa-romero       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two  convertible          rwd           front        88.6  ...
# 3          two    hatchback          rwd           front        94.5  ...
# 4         four        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
auto_prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          206 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               206 non-null    str
#  3   fuel-type          206 non-null    str
#  4   aspiration         206 non-null    str
#  5   num-of-doors       204 non-null    str
#  6   body-style         206 non-null    str
#  7   drive-wheels       206 non-null    str
#  8   engine-location    206 non-null    str
#  9   wheel-base         206 non-null    float64
#  10  length             206 non-null    float64
#  11  width              206 non-null    float64
#  12  height             206 non-null    float64
#  13  curb-weight        206 non-null    int64
#  14  engine-type        206 non-null    str
#  15  num-of-cylinders   206 non-null    str
# ...

# %%
#### Ex 3

# %%
df = pd.read_csv('../Datasets/houses_to_rent_to_fix.csv')
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70    2.0         1               1     7      acept
# 1     São Paulo   320    NaN         4               0    20      acept
# 2  Porto Alegre    80    1.0         1               1     6      acept
# 3  Porto Alegre    51    NaN         1               0     2      acept
# 4     São Paulo    25    1.0         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# ...

# %%
df.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  4
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %%
mode_value = df['rooms'].mode()[0]
df['rooms'] = df['rooms'].fillna(mode_value)

# %%
mode_value
# Out:
# np.float64(3.0)

# %%
df.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %%
df
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           São Paulo    70    2.0         1               1     7      acept
# 1           São Paulo   320    3.0         4               0    20      acept
# 2        Porto Alegre    80    1.0         1               1     6      acept
# 3        Porto Alegre    51    3.0         1               0     2      acept
# 4           São Paulo    25    1.0         1               0     1  not acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 10687    Porto Alegre    63    2.0         1               1     5  not acept
# 10688       São Paulo   285    4.0         4               4    17      acept
# 10689  Rio de Janeiro    70    3.0         3               0     8  not acept
# 10690  Rio de Janeiro   120    2.0         2               2     8      acept
# 10691       São Paulo    80    2.0         1               0     -      acept
#
# ...

# %%
#### Ex 4

# %%
df['area']
# Out:
# 0         70
# 1        320
# 2         80
# 3         51
# 4         25
#         ...
# 10687     63
# 10688    285
# 10689     70
# 10690    120
# 10691     80
# Name: area, Length: 10692, dtype: int64

# %%
df[df['area']>250]
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 1           São Paulo   320    3.0         4               0    20      acept
# 5           São Paulo   376    3.0         3               7     -      acept
# 15           Campinas   330    4.0         6               6     -      acept
# 19          São Paulo   600    4.0         5               6     -      acept
# 34          São Paulo   350    4.0         4               3     8      acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 10646  Rio de Janeiro   300    3.0         4               1    10      acept
# 10664  Rio de Janeiro   310    3.0         2               0     5  not acept
# 10669       São Paulo   340    4.0         5               3    15  not acept
# 10683       São Paulo   280    4.0         4               2     5      acept
# 10688       São Paulo   285    4.0         4               4    17      acept
#
# ...

# %%
df.sort_values('area')
# Out:
#                 city   area  rooms  bathroom  parking spaces floor     animal  \
# 785        São Paulo     11    1.0         1               0     1  not acept
# 6784       São Paulo     12    1.0         1               0     -  not acept
# 1588       São Paulo     13    1.0         1               0     2      acept
# 4864       São Paulo     13    1.0         1               0     1      acept
# 1606  Belo Horizonte     15    1.0         1               0     -      acept
# ...              ...    ...    ...       ...             ...   ...        ...
# 5129  Belo Horizonte   2000    4.0         2               3     -      acept
# 8790  Belo Horizonte   2000    3.0         3               2     2      acept
# 9241        Campinas  12732    3.0         2               0     3      acept
# 5915       São Paulo  24606    5.0         4               4    12      acept
# 2397  Belo Horizonte  46335    4.0         8               5    11      acept
#
# ...

# %%
#### Ex 5

# %%
auto_prices
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN      ferrari       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            3                NaN  alfa-romero       gas        std
# 3            1                NaN  alfa-romero       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo       gas      turbo
# 203         -1               95.0        volvo       gas        std
# 204         -1               95.0        volvo    diesel      turbo
# 205         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
auto_prices['engine-size'].plot(kind='line')
# Out:
# <Axes: >

# %%
ax = auto_prices['engine-size'].plot(kind='line')

ax.set_title('Engine Size Distribution')
ax.set_xlabel('Index')
ax.set_ylabel('Engine Size')
# Out:
# Text(0, 0.5, 'Engine Size')
